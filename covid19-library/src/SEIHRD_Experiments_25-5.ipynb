# %% [markdown]
# # SEIR model class experiments

# %% [markdown]
# Utilities for train, forecasting and plotting are now provided in nb_utils.
# Documentation for the helper functions are available as docstrings.
#
# Set the appropriate training parameters and forecast parameters in the
# corresponding cells.
#
# train_eval
# > Train and evaluate models (currently we only support SEIR family).
#   Default configuration parameters for train and test files are
#   provided as train_config.json and test_config.json respectively.
#   Search paramters, loss functions etc, are specified in the config
#   files.
#
# forecast, plot
# > Generate forecasts using a trained model and plotting utilities.

# %%
import json
import pandas as pd
import mlflow
import os

from datetime import datetime, timedelta

from nb_utils import train_eval
from nb_utils import forecast
from nb_utils import plot
from nb_utils import plot_m1, plot_m2, plot_m3
from nb_utils import train_eval_plot
from nb_utils import parse_metrics

# %% [markdown]
# ## Load default configurations

# %%
with open('train_config.json') as f_train, \
    open('test_config.json') as f_test, \
    open('forecast_config.json') as f_forecast:
    default_train_config = json.load(f_train)
    default_test_config = json.load(f_test)
    default_forecast_config = json.load(f_forecast)

# %% [markdown]
# ## Set the model class

# %%
model_class = 'SEIHRD'
default_train_config['model_class'] = model_class
default_test_config['model_class'] = model_class
default_forecast_config['model_class'] = model_class

# %% [markdown]
# ## Optional: Modify training loss function

# %%
variable_and_weights = [('confirmed', 0.25) , ('recovered', 0.25), ('deceased', 0.25), ('hospitalized', 0.25)]
weights = {'metric_name' : 'mape', 'variable_weights' : []}
for (variable, weight) in variable_and_weights:
    weights['variable_weights'].append({
        "variable" : variable,
        "weight" : weight
    })
default_train_config['training_loss_function'].update(weights)

# %% [markdown]
# ## Training parameters

# %%
region = 'indore'
region_type = 'district'

# %%
#Current day : Last day without the flattening of counts
current_day = datetime.now().date() - timedelta(1)

# Train1 : 1 week interval starting 2 weeks prior to current day
train1_start_date = current_day - timedelta(14)
train1_end_date = current_day - timedelta(8)
train1_run_day = train1_start_date - timedelta(1)

train1_start_date = train1_start_date.strftime("%-m/%-d/%y")
train1_end_date = train1_end_date.strftime("%-m/%-d/%y")
train1_run_day = train1_run_day.strftime("%-m/%-d/%y")

# Train2 : 1 week interval starting 1 week prior to current day
train2_start_date = current_day - timedelta(7)
train2_end_date = current_day
train2_run_day = train2_start_date - timedelta(1)

train2_start_date = train2_start_date.strftime("%-m/%-d/%y")
train2_end_date = train2_end_date.strftime("%-m/%-d/%y")
train2_run_day = train2_run_day.strftime("%-m/%-d/%y")

# Test: 1 week interval prior to current day
test_start_date = current_day - timedelta(7)
test_end_date = current_day
test_run_day = test_start_date - timedelta(1)

test_start_date = test_start_date.strftime("%-m/%-d/%y")
test_end_date = test_end_date.strftime("%-m/%-d/%y")
test_run_day = test_run_day.strftime("%-m/%-d/%y")

# %% [markdown]
# ## train_eval on the region of interest

# %%
params, metrics, train1_params, train2_params = train_eval(region, region_type, 
                                                           train1_start_date, train1_end_date, 
                                                           train2_start_date, train2_end_date, train2_run_day,
                                                           test_start_date, test_end_date,
                                                           default_train_config, default_test_config,
                                                           max_evals = 1000,
                                                           mlflow_log = False,
                                                           name_prefix = region)
# Out:
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# ...
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# 100%|██████████| 1000/1000 [02:00<00:00,  8.33trial/s, best loss: 2.209859107997608]
# Best fit: {'EbyCRatio': 0.07483882195348268, 'F_fatalities': 0.07921456293534071, 'F_hospitalization': 0.0023672878655606328, 'IbyCRatio': 0.19016905364962353, 'infectious_period': 6.000336125454354, 'r0': 0.8462440168346645}
# Best Loss: 2.209859107997608
# t = 8.90
# t = 8.90

# %% [markdown]
# ## Inspect model parameters

# %%
train1_params
# Out:
# {'model_parameters': {'EbyCRatio': 0.03863156747960124,
#   'F_fatalities': 0.07698436201381559,
#   'F_hospitalization': 0.004950006216880813,
#   'F_icu': 0.05,
#   'IbyCRatio': 0.5558619886166973,
#   'LatentEbyCRatio': {'5/10/20': 0.03863156747960124,
#    '5/17/20': 0.21788072891080298},
#   'LatentIbyCRatio': {'5/10/20': 0.5558619886166973,
#    '5/17/20': 0.46536965319000423},
#   'MAPE': 4.198560155211391,
#   'incubation_period': 5,
#   'infectious_period': 9.714129902385107,
#   'r0': 0.7855938191479952},
#  'model_type': 'SEIHRD',
#  'region': 'indore',
#  'region_type': 'district'}

# %%
train2_params
# Out:
# {'model_parameters': {'EbyCRatio': 0.07483882195348268,
#   'F_fatalities': 0.07921456293534071,
#   'F_hospitalization': 0.0023672878655606328,
#   'F_icu': 0.05,
#   'IbyCRatio': 0.19016905364962353,
#   'LatentEbyCRatio': {'5/17/20': 0.07483882195348268,
#    '5/25/20': 0.0986644946949449},
#   'LatentIbyCRatio': {'5/17/20': 0.19016905364962353,
#    '5/25/20': 0.504020969007905},
#   'MAPE': 2.209859107997608,
#   'incubation_period': 5,
#   'infectious_period': 6.000336125454354,
#   'r0': 0.8462440168346645},
#  'model_type': 'SEIHRD',
#  'region': 'indore',
#  'region_type': 'district'}

# %%
metrics
# Out:
# {'TestMAPE': 40.051351490918485,
#  'TestRMLSE': 0,
#  'Test_mape_confirmed': 6.80814609810352,
#  'Test_mape_confirmed_weight': 1.0,
#  'Test_mape_deceased': 9.323511030265449,
#  'Test_mape_deceased_weight': 1.0,
#  'Test_mape_hospitalized': 5.030094539718215,
#  'Test_mape_hospitalized_weight': 1.0,
#  'Test_mape_recovered': 10.879329524647604,
#  'Test_mape_recovered_weight': 1.0,
#  'Train1MAPE': 33.58848124169113,
#  'Train1RMLSE': 0,
#  'Train1_EbyCRatio': 0.03863156747960124,
#  'Train1_F_fatalities': 0.07698436201381559,
#  'Train1_F_hospitalization': 0.004950006216880813,
#  'Train1_IbyCRatio': 0.5558619886166973,
#  'Train1_LatentEbyCRatio_5/10/20': 0.03863156747960124,
#  'Train1_LatentEbyCRatio_5/17/20': 0.21788072891080298,
#  'Train1_LatentIbyCRatio_5/10/20': 0.5558619886166973,
#  'Train1_LatentIbyCRatio_5/17/20': 0.46536965319000423,
#  'Train1_infectious_period': 9.714129902385107,
#  'Train1_mape_confirmed': 1.4327464384194761,
#  'Train1_mape_confirmed_weight': 1.0,
#  'Train1_mape_deceased': 6.149307320375511,
#  'Train1_mape_deceased_weight': 1.0,
#  'Train1_mape_hospitalized': 2.693144093542687,
#  'Train1_mape_hospitalized_weight': 1.0,
#  'Train1_mape_recovered': 6.519042768507887,
#  'Train1_mape_recovered_weight': 1.0,
#  'Train1_r0': 0.7855938191479952,
#  'Train2MAPE': 17.678872863980864,
#  'Train2RMLSE': 0,
#  'Train2_EbyCRatio': 0.07483882195348268,
#  'Train2_F_fatalities': 0.07921456293534071,
#  'Train2_F_hospitalization': 0.0023672878655606328,
#  'Train2_IbyCRatio': 0.19016905364962353,
#  'Train2_LatentEbyCRatio_5/17/20': 0.07483882195348268,
#  'Train2_LatentEbyCRatio_5/25/20': 0.0986644946949449,
#  'Train2_LatentIbyCRatio_5/17/20': 0.19016905364962353,
#  'Train2_LatentIbyCRatio_5/25/20': 0.504020969007905,
#  'Train2_infectious_period': 6.000336125454354,
#  'Train2_mape_confirmed': 1.490487950246228,
#  'Train2_mape_confirmed_weight': 1.0,
#  'Train2_mape_deceased': 0.9655688510480362,
#  'Train2_mape_deceased_weight': 1.0,
#  'Train2_mape_hospitalized': 2.6914909291430353,
#  'Train2_mape_hospitalized_weight': 1.0,
#  'Train2_mape_recovered': 3.6918887015531325,
#  'Train2_mape_recovered_weight': 1.0,
#  'Train2_r0': 0.8462440168346645}

# %% [markdown]
# ## Generate Plots

# %%
# %matplotlib inline
plot_m1(train1_params, train1_run_day, train1_start_date, train1_end_date, 
        test_run_day, test_start_date, test_end_date, 
        rolling_average = False, uncertainty = False, 
        plot_config = 'plot_config.json', plot_name = region+'_m1.png')
# Out:
# t = 7.90
# /Users/nayana/.local/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# t = 8.90
# /Users/nayana/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# %matplotlib inline
plot_m2(train2_params, train1_start_date, train1_end_date, 
        test_run_day, test_start_date, test_end_date, plot_name = region+ '_m2.png')
# Out:
# t = 8.90
# /Users/nayana/.local/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
# %matplotlib inline
forecast_start_date = train2_start_date
forecast_length = 30 # Forecast for 30 days
plot_m3(train2_params, train1_start_date, 
        forecast_start_date, forecast_length, plot_name = region +'_m3.png')
# Out:
# t = 31.90
# /Users/nayana/.local/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %% [markdown]
# ## MLflow Setup

# %% [markdown]
# Set MLflow username, password and experiment.

# %%
# os.environ['MLFLOW_TRACKING_USERNAME'] = <username>
# os.environ['MLFLOW_TRACKING_PASSWORD'] = <password>

mlflow.set_tracking_uri("http://ec2-54-175-207-176.compute-1.amazonaws.com")
mlflow.set_experiment("seir_trial")

# %% [markdown]
# ## Run Experiments

# %%
experiments = [{'region':'jaipur','region_type':'district'},
              {'region':'ahmedabad','region_type':'district'}]

current_day = datetime.now().date() - timedelta(1)
forecast_length = 30

# %%
for experiment in experiments:
    train_eval_plot(experiment['region'], experiment['region_type'], 
                    current_day, forecast_length,
                    default_train_config, default_test_config,
                    max_evals = 1000, data_source = 'district_daily', 
                    mlflow_log = True)
# Out:
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# ...
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# 100%|██████████| 1000/1000 [02:47<00:00,  5.97trial/s, best loss: 9.338801373328273]
# Best fit: {'EbyCRatio': 0.14780016077959685, 'F_fatalities': 0.1199682427127581, 'F_hospitalization': 0.002705494326419212, 'IbyCRatio': 0.1836540508892765, 'infectious_period': 9.682828131137061, 'r0': 2.405781236219625}
# Best Loss: 9.338801373328273
# t = 8.90
# t = 8.90
# t = 7.90
# t = 8.90
# t = 8.90
# t = 31.90
