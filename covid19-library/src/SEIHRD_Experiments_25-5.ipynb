# %% [markdown]
# # SEIR model class experiments

# %% [markdown]
# Utilities for train, forecasting and plotting are now provided in nb_utils.
# Documentation for the helper functions are available as docstrings.
#
# Set the appropriate training parameters and forecast parameters in the
# corresponding cells.
#
# train_eval
# > Train and evaluate models (currently we only support SEIR family).
#   Default configuration parameters for train and test files are
#   provided as train_config.json and test_config.json respectively.
#   Search paramters, loss functions etc, are specified in the config
#   files.
#
# forecast, plot
# > Generate forecasts using a trained model and plotting utilities.

# %%
import json
import pandas as pd

from datetime import datetime, timedelta

from nb_utils import train_eval
from nb_utils import forecast
from nb_utils import plot
from nb_utils import plot_m1, plot_m2, plot_m3

# %% [markdown]
# ## Load default configurations

# %%
with open('train_config.json') as f_train, \
    open('test_config.json') as f_test, \
    open('forecast_config.json') as f_forecast:
    default_train_config = json.load(f_train)
    default_test_config = json.load(f_test)
    default_forecast_config = json.load(f_forecast)

# %% [markdown]
# ## Set the model class

# %%
model_class = 'SEIHRD'
default_train_config['model_class'] = model_class
default_test_config['model_class'] = model_class
default_forecast_config['model_class'] = model_class

# %% [markdown]
# ## Optional: Modify training loss function

# %%
variable_and_weights = [('confirmed', 1.0) , ('recovered', 1.0), ('deceased', 1.0), ('hospitalized', 1.0)]
weights = {'metric_name' : 'mape', 'variable_weights' : []}
for (variable, weight) in variable_and_weights:
    weights['variable_weights'].append({
        "variable" : variable,
        "weight" : weight
    })
default_train_config['training_loss_function'].update(weights)

# %% [markdown]
# ## Training parameters

# %%
region = 'jaipur'
region_type = 'district'

# %%
#Current day : Last day without the flattening of counts
current_day = datetime.now().date() - timedelta(4)

# Train1 : 1 week interval starting 2 weeks prior to current day
train1_start_date = current_day - timedelta(14)
train1_end_date = current_day - timedelta(8)
train1_run_day = train1_start_date - timedelta(1)

train1_start_date = train1_start_date.strftime("%-m/%-d/%y")
train1_end_date = train1_end_date.strftime("%-m/%-d/%y")
train1_run_day = train1_run_day.strftime("%-m/%-d/%y")

# Train2 : 1 week interval starting 1 week prior to current day
train2_start_date = current_day - timedelta(7)
train2_end_date = current_day
train2_run_day = train2_start_date - timedelta(1)

train2_start_date = train2_start_date.strftime("%-m/%-d/%y")
train2_end_date = train2_end_date.strftime("%-m/%-d/%y")
train2_run_day = train2_run_day.strftime("%-m/%-d/%y")

# Test: 1 week interval prior to current day
test_start_date = current_day - timedelta(7)
test_end_date = current_day
test_run_day = test_start_date - timedelta(1)

test_start_date = test_start_date.strftime("%-m/%-d/%y")
test_end_date = test_end_date.strftime("%-m/%-d/%y")
test_run_day = test_run_day.strftime("%-m/%-d/%y")

# %% [markdown]
# ## train_eval on the region of interest

# %%
params, metrics, train1_params, train2_params = train_eval(region, region_type, 
                                                           train1_start_date, train1_end_date, 
                                                           train2_start_date, train2_end_date, train2_run_day,
                                                           test_start_date, test_end_date,
                                                           default_train_config, default_test_config,
                                                           max_evals = 1000,
                                                           mlflow_log = False,
                                                           name_prefix = 'mumbai_sample');
# Out:
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# ...
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# 100%|██████████| 1000/1000 [02:25<00:00,  6.87trial/s, best loss: 107.49501029835776]
# Best fit: {'EbyCRatio': 0.022328784093222843, 'F_fatalities': 0.05163303856684576, 'F_hospitalization': 0.040118917342097465, 'IbyCRatio': 0.3273637118546184, 'infectious_period': 8.540839305588433, 'r0': 1.255668686188113}
# Best Loss: 107.49501029835776
# t = 8.90
# t = 8.90

# %% [markdown]
# ## Inspect model parameters

# %%
train1_params
# Out:
# {'model_parameters': {'EbyCRatio': 0.0895625656580899,
#   'F_fatalities': 0.05879322790602592,
#   'F_hospitalization': 0.04199706763344993,
#   'F_icu': 0.05,
#   'IbyCRatio': 0.21188070932189584,
#   'LatentEbyCRatio': {'5/13/20': 0.627804337687181,
#    '5/6/20': 0.0895625656580899},
#   'LatentIbyCRatio': {'5/13/20': 0.10551680459919872,
#    '5/6/20': 0.21188070932189584},
#   'MAPE': 96.86422844358293,
#   'incubation_period': 5,
#   'infectious_period': 7.250075072336127,
#   'r0': 3.089856452936743},
#  'model_type': 'SEIHRD',
#  'region': 'jaipur',
#  'region_type': 'district'}

# %%
train2_params
# Out:
# {'model_parameters': {'EbyCRatio': 0.022328784093222843,
#   'F_fatalities': 0.05163303856684576,
#   'F_hospitalization': 0.040118917342097465,
#   'F_icu': 0.05,
#   'IbyCRatio': 0.3273637118546184,
#   'LatentEbyCRatio': {'5/13/20': 0.022328784093222843,
#    '5/21/20': 0.2491490510037087},
#   'LatentIbyCRatio': {'5/13/20': 0.3273637118546184,
#    '5/21/20': 0.08009184405293279},
#   'MAPE': 107.49501029835776,
#   'incubation_period': 5,
#   'infectious_period': 8.540839305588433,
#   'r0': 1.255668686188113},
#  'model_type': 'SEIHRD',
#  'region': 'jaipur',
#  'region_type': 'district'}

# %%
metrics
# Out:
# {'TestAll': [{'metric_name': <MetricName.mape: 'mape'>,
#    'value': 6.975305827310415,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.rmsle: 'rmsle'>,
#    'value': 0.0960395060230434,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0}]}],
#  'TestMAPE': 6.975305827310415,
#  'TestRMLSE': 0.0960395060230434,
#  'Train1All': [{'metric_name': <MetricName.mape: 'mape'>,
#    'value': 96.86422844358293,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0},
#     {'variable': <ForecastVariable.recovered: 'recovered'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.deceased: 'deceased'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 2.2501559867235006,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 53.42610843948945,
#    'variable_weights': [{'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 29.756461998417688,
#    'variable_weights': [{'variable': <ForecastVariable.recovered: 'recovered'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 11.431502018952289,
#    'variable_weights': [{'variable': <ForecastVariable.deceased: 'deceased'>,
#      'weight': 1.0}]}],
#  'Train1MAPE': 193.72845688716586,
#  'Train1RMLSE': 0,
#  'Train1_EbyCRatio': 0.0895625656580899,
#  'Train1_F_fatalities': 0.05879322790602592,
#  'Train1_F_hospitalization': 0.04199706763344993,
#  'Train1_IbyCRatio': 0.21188070932189584,
#  'Train1_LatentEbyCRatio_5/13/20': 0.627804337687181,
#  'Train1_LatentEbyCRatio_5/6/20': 0.0895625656580899,
#  'Train1_LatentIbyCRatio_5/13/20': 0.10551680459919872,
#  'Train1_LatentIbyCRatio_5/6/20': 0.21188070932189584,
#  'Train1_infectious_period': 7.250075072336127,
#  'Train1_r0': 3.089856452936743,
#  'Train2All': [{'metric_name': <MetricName.mape: 'mape'>,
#    'value': 107.49501029835776,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0},
#     {'variable': <ForecastVariable.recovered: 'recovered'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.deceased: 'deceased'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 2.2897639626160773,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 62.37244016348951,
#    'variable_weights': [{'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 35.35255673969891,
#    'variable_weights': [{'variable': <ForecastVariable.recovered: 'recovered'>,
#      'weight': 1.0}]},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'value': 7.480249432553252,
#    'variable_weights': [{'variable': <ForecastVariable.deceased: 'deceased'>,
#      'weight': 1.0}]}],
#  'Train2MAPE': 214.9900205967155,
#  'Train2RMLSE': 0,
#  'Train2_EbyCRatio': 0.022328784093222843,
#  'Train2_F_fatalities': 0.05163303856684576,
#  'Train2_F_hospitalization': 0.040118917342097465,
#  'Train2_IbyCRatio': 0.3273637118546184,
#  'Train2_LatentEbyCRatio_5/13/20': 0.022328784093222843,
#  'Train2_LatentEbyCRatio_5/21/20': 0.2491490510037087,
#  'Train2_LatentIbyCRatio_5/13/20': 0.3273637118546184,
#  'Train2_LatentIbyCRatio_5/21/20': 0.08009184405293279,
#  'Train2_infectious_period': 8.540839305588433,
#  'Train2_r0': 1.255668686188113}

# %% [markdown]
# ## Generate Plots

# %%
# %matplotlib inline
plot_m1(train1_params, train1_run_day, train1_start_date, train1_end_date, 
        test_run_day, test_start_date, test_end_date, 
        rolling_average = False, uncertainty = False, 
        plot_config = 'plot_config.json', plot_name = 'jaipur_m1.png')
# Out:
# t = 7.90
# /Users/nayana/.local/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# t = 8.90

# %%
# %matplotlib inline
plot_m2(train2_params, train1_start_date, train1_end_date, 
        test_run_day, test_start_date, test_end_date, plot_name = 'jaipur_m2.png')
# Out:
# t = 8.90
# /Users/nayana/.local/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
# %matplotlib inline
forecast_start_date = train2_start_date
forecast_length = 30 # Forecast for 30 days
plot_m3(train2_params, train1_start_date, 
        forecast_start_date, forecast_length, plot_name = 'jaipur_m3.png')
# Out:
# t = 31.90
# /Users/nayana/.local/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
