# %% [markdown]
# # SEIR model class experiments

# %% [markdown]
# Utilities for train, forecasting and plotting are now provided in nb_utils.
# Documentation for the helper functions are available as docstrings.
#
# Set the appropriate training parameters and forecast parameters in the
# corresponding cells.
#
# train_eval
# > Train and evaluate models (currently we only support SEIR family).
#   Default configuration parameters for train and test files are
#   provided as train_config.json and test_config.json respectively.
#   Search paramters, loss functions etc, are specified in the config
#   files.
#
# forecast, plot
# > Generate forecasts using a trained model and plotting utilities.

# %%
import json
import pandas as pd

from datetime import datetime, timedelta

from nb_utils import train_eval
from nb_utils import forecast
from nb_utils import plot
from nb_utils import plot_m1, plot_m2, plot_m3

# %% [markdown]
# ## Load default configurations

# %%
with open('train_config.json') as f_train, \
    open('test_config.json') as f_test, \
    open('forecast_config.json') as f_forecast:
    default_train_config = json.load(f_train)
    default_test_config = json.load(f_test)
    default_forecast_config = json.load(f_forecast)

# %% [markdown]
# ## Set the model class

# %%
model_class = 'SEIHRD'
default_train_config['model_class'] = model_class
default_test_config['model_class'] = model_class
default_forecast_config['model_class'] = model_class

# %% [markdown]
# ## Optional: Modify training loss function

# %%
variable_and_weights = [('confirmed', 0.25) , ('recovered', 0.25), ('deceased', 0.25), ('hospitalized', 0.25)]
weights = {'metric_name' : 'mape', 'variable_weights' : []}
for (variable, weight) in variable_and_weights:
    weights['variable_weights'].append({
        "variable" : variable,
        "weight" : weight
    })
default_train_config['training_loss_function'].update(weights)

# %% [markdown]
# ## Training parameters

# %%
region = 'indore'
region_type = 'district'

# %%
#Current day : Last day without the flattening of counts
current_day = datetime.now().date() - timedelta(1)

# Train1 : 1 week interval starting 2 weeks prior to current day
train1_start_date = current_day - timedelta(14)
train1_end_date = current_day - timedelta(8)
train1_run_day = train1_start_date - timedelta(1)

train1_start_date = train1_start_date.strftime("%-m/%-d/%y")
train1_end_date = train1_end_date.strftime("%-m/%-d/%y")
train1_run_day = train1_run_day.strftime("%-m/%-d/%y")

# Train2 : 1 week interval starting 1 week prior to current day
train2_start_date = current_day - timedelta(7)
train2_end_date = current_day
train2_run_day = train2_start_date - timedelta(1)

train2_start_date = train2_start_date.strftime("%-m/%-d/%y")
train2_end_date = train2_end_date.strftime("%-m/%-d/%y")
train2_run_day = train2_run_day.strftime("%-m/%-d/%y")

# Test: 1 week interval prior to current day
test_start_date = current_day - timedelta(7)
test_end_date = current_day
test_run_day = test_start_date - timedelta(1)

test_start_date = test_start_date.strftime("%-m/%-d/%y")
test_end_date = test_end_date.strftime("%-m/%-d/%y")
test_run_day = test_run_day.strftime("%-m/%-d/%y")

# %% [markdown]
# ## train_eval on the region of interest

# %%
params, metrics, train1_params, train2_params = train_eval(region, region_type, 
                                                           train1_start_date, train1_end_date, 
                                                           train2_start_date, train2_end_date, train2_run_day,
                                                           test_start_date, test_end_date,
                                                           default_train_config, default_test_config,
                                                           max_evals = 1000,
                                                           mlflow_log = False,
                                                           name_prefix = region);
# Out:
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# t = 7.90
# ...
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# t = 8.90
# 100%|██████████| 1000/1000 [01:42<00:00,  9.73trial/s, best loss: 64.2647666208739]
# Best fit: {'EbyCRatio': 0.06719868838592835, 'F_fatalities': 0.0647374488081981, 'F_hospitalization': 0.010159699723274272, 'IbyCRatio': 0.3699470460716252, 'infectious_period': 9.687425970504655, 'r0': 1.5492341404883283}
# Best Loss: 64.2647666208739
# t = 8.90
# t = 8.90

# %% [markdown]
# ## Inspect model parameters

# %%
train1_params
# Out:
# {'region': 'indore',
#  'region_type': 'district',
#  'model_type': 'SEIHRD',
#  'model_parameters': {'incubation_period': 5,
#   'F_icu': 0.05,
#   'EbyCRatio': 0.07274760599508634,
#   'F_fatalities': 0.08245904391601305,
#   'F_hospitalization': 0.010008331110678552,
#   'IbyCRatio': 0.4424931333540336,
#   'infectious_period': 9.832349531393824,
#   'r0': 1.7114924045902733,
#   'LatentEbyCRatio': {'5/9/20': 0.07274760599508634,
#    '5/16/20': 0.5099833442976579},
#   'LatentIbyCRatio': {'5/9/20': 0.4424931333540336,
#    '5/16/20': 0.38848693641140886},
#   'MAPE': 35.492731094835754}}

# %%
train2_params
# Out:
# {'region': 'indore',
#  'region_type': 'district',
#  'model_type': 'SEIHRD',
#  'model_parameters': {'incubation_period': 5,
#   'F_icu': 0.05,
#   'EbyCRatio': 0.06719868838592835,
#   'F_fatalities': 0.0647374488081981,
#   'F_hospitalization': 0.010159699723274272,
#   'IbyCRatio': 0.3699470460716252,
#   'infectious_period': 9.687425970504655,
#   'r0': 1.5492341404883283,
#   'LatentEbyCRatio': {'5/16/20': 0.06719868838592835,
#    '5/24/20': 0.41889832415755146},
#   'LatentIbyCRatio': {'5/16/20': 0.3699470460716252,
#    '5/24/20': 0.3432859906035557},
#   'MAPE': 64.2647666208739}}

# %%
metrics
# Out:
# {'Train1RMLSE': 0,
#  'Train1MAPE': 70.98546218967151,
#  'Train1All': [{'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0},
#     {'variable': <ForecastVariable.recovered: 'recovered'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.deceased: 'deceased'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}],
#    'value': 35.492731094835754},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0}],
#    'value': 0.5544495925705626},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}],
#    'value': 12.413730201401345},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.recovered: 'recovered'>,
#      'weight': 1.0}],
#    'value': 11.758290901209595},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.deceased: 'deceased'>,
#      'weight': 1.0}],
#    'value': 10.766260399654252}],
#  'Train1_EbyCRatio': 0.07274760599508634,
#  'Train1_F_fatalities': 0.08245904391601305,
#  'Train1_F_hospitalization': 0.010008331110678552,
#  'Train1_IbyCRatio': 0.4424931333540336,
#  'Train1_infectious_period': 9.832349531393824,
#  'Train1_r0': 1.7114924045902733,
#  'Train1_LatentEbyCRatio_5/9/20': 0.07274760599508634,
#  'Train1_LatentEbyCRatio_5/16/20': 0.5099833442976579,
#  'Train1_LatentIbyCRatio_5/9/20': 0.4424931333540336,
#  'Train1_LatentIbyCRatio_5/16/20': 0.38848693641140886,
#  'TestMAPE': 105.26965726862574,
#  'TestRMLSE': 0,
#  'TestAll': [{'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 0.25},
#     {'variable': <ForecastVariable.recovered: 'recovered'>, 'weight': 0.25},
#     {'variable': <ForecastVariable.deceased: 'deceased'>, 'weight': 0.25},
#     {'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 0.25}],
#    'value': 21.053931453725145},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0}],
#    'value': 9.463001114109252},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}],
#    'value': 10.130031551688903},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.recovered: 'recovered'>,
#      'weight': 1.0}],
#    'value': 29.52249544615379},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.deceased: 'deceased'>,
#      'weight': 1.0}],
#    'value': 35.10019770294864}],
#  'Train2MAPE': 128.5295332417478,
#  'Train2RMLSE': 0,
#  'Train2All': [{'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0},
#     {'variable': <ForecastVariable.recovered: 'recovered'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.deceased: 'deceased'>, 'weight': 1.0},
#     {'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}],
#    'value': 64.2647666208739},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.confirmed: 'confirmed'>,
#      'weight': 1.0}],
#    'value': 2.261825491762855},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.hospitalized: 'hospitalized'>,
#      'weight': 1.0}],
#    'value': 22.212077871777453},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.recovered: 'recovered'>,
#      'weight': 1.0}],
#    'value': 29.704789622294985},
#   {'metric_name': <MetricName.mape: 'mape'>,
#    'variable_weights': [{'variable': <ForecastVariable.deceased: 'deceased'>,
#      'weight': 1.0}],
#    'value': 10.086073635038613}],
#  'Train2_EbyCRatio': 0.06719868838592835,
#  'Train2_F_fatalities': 0.0647374488081981,
#  'Train2_F_hospitalization': 0.010159699723274272,
#  'Train2_IbyCRatio': 0.3699470460716252,
#  'Train2_infectious_period': 9.687425970504655,
#  'Train2_r0': 1.5492341404883283,
#  'Train2_LatentEbyCRatio_5/16/20': 0.06719868838592835,
#  'Train2_LatentEbyCRatio_5/24/20': 0.41889832415755146,
#  'Train2_LatentIbyCRatio_5/16/20': 0.3699470460716252,
#  'Train2_LatentIbyCRatio_5/24/20': 0.3432859906035557}

# %% [markdown]
# ## Generate Plots

# %%
# %matplotlib inline
plot_m1(train1_params, train1_run_day, train1_start_date, train1_end_date, 
        test_run_day, test_start_date, test_end_date, 
        rolling_average = False, uncertainty = False, 
        plot_config = 'plot_config.json', plot_name = region+'_m1.png')
# Out:
# t = 7.90
# t = 8.90

# %%
# %matplotlib inline
plot_m2(train2_params, train1_start_date, train1_end_date, 
        test_run_day, test_start_date, test_end_date, plot_name = region+ '_m2.png')
# Out:
# t = 8.90

# %%
# %matplotlib inline
forecast_start_date = train2_start_date
forecast_length = 120 # Forecast for 30 days
plot_m3(train2_params, train1_start_date, 
        forecast_start_date, forecast_length, plot_name = region +'_m3.png')
# Out:
# t = 121.90
